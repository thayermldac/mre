# %%
# %matplotlib inline 

# Basics
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# Keras
import keras
import keras.backend as K
from keras.models import Model, load_model
from keras.layers import Input, Dense, Conv2D, Lambda, UpSampling2D
from keras.layers import Dot, dot, Dropout, BatchNormalization

# Others
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
# Load Dataset
df=pd.read_msgpack('MREdata_072118.msg')

# %%
# Prepare Data
Ur = np.stack(df.Ur.values,axis=3).transpose(3,0,1,2)
Ui = np.stack(df.Ui.values,axis=3).transpose(3,0,1,2)
x_data = np.sqrt(Ui**2+Ur**2)

y_data = np.stack(df.RS.values,axis=2).transpose(2,0,1)
y_data = y_data/10000.

print 'X size:', x_data.shape
print 'Y size:', y_data.shape
# Out:
# X size: (612, 64, 64, 3)
# Y size: (612, 64, 64)

# %%
# Split to Train & Valid
x_train, x_test, y_train, y_test = train_test_split(x_data,y_data,test_size=0.3)
x_train, x_valid, y_train, y_valid = train_test_split(x_train,y_train,test_size=0.3)

print 'Training examples:   ', len(x_train)
print 'Validation examples: ', len(x_valid)
print 'Testing examples:    ', len(x_test)
# Out:
# Training examples:    299
# Validation examples:  129
# Testing examples:     184

# %% [markdown]
# ### Building Neural Network

# %%
def laplace(x):
    # Make Kernel
    a = np.asarray([[0., 1., 0.],
                    [1.,-4., 1.],
                    [0., 1., 0.]])    
#     a = np.asarray([[0.5, 1.0, 0.5],
#                     [1.0, -6., 1.0],
#                     [0.5, 1.0, 0.5]])
    a = a.reshape(list(a.shape) + [1,1])
    kernel = K.constant(a,dtype=1)
    
    # Do Convolution
    x = K.expand_dims(K.expand_dims(x, 0), -1)
    y = K.depthwise_conv2d(x,kernel, padding='same')
    
    return y[0,:,:,0]

def laplacian(x):
    u = K.tf.norm(x,axis=3)
    return K.map_fn(laplace,u)

# %%
# Parameters
xshp   = x_train.shape[1:]
nbatch = 16
nepoch = 200

# Architecture
L1 = 64
L2 = 50
L3 = 32
L4 = 50

# %%
# Build Neural Model

# Encoding
x  = Input(shape=xshp,name='Input')
h  = Conv2D(L1,kernel_size=(5,5),strides=(2,2),activation='relu',padding='same',name='E1')(x)
# h  = BatchNormalization()(h)
h  = Conv2D(L2,kernel_size=(3,3),strides=(2,2),activation='relu',padding='same',name='E2')(h)
# h  = BatchNormalization()(h)
h  = Conv2D(L3,kernel_size=(3,3),strides=(2,2),activation='relu',padding='same',name='E3')(h)
# h  = BatchNormalization()(h)
e  = Conv2D(L4,kernel_size=(2,2),strides=(1,1),activation='relu',padding='same',name='E4')(h)

# Decoding
h  = Conv2D(L4,kernel_size=(2,2),activation='relu',padding='same',name='D1')(e)
h  = UpSampling2D((2,2))(h)
h  = Conv2D(L3,kernel_size=(3,3),activation='relu',padding='same',name='D2')(h)
h  = UpSampling2D((2,2))(h)
h  = Conv2D(L2,kernel_size=(3,3),activation='relu',padding='same',name='D3')(h)
h  = UpSampling2D((2,2))(h)
h  = Conv2D(1,kernel_size=(5,5),activation='relu',padding='same',name='D4')(h)
y  = Lambda(lambda xx: K.squeeze(xx,3),name='Recon')(h)

# Laplacian
l = Lambda(laplacian,name='Laplacian')(x)
z = dot([y,l],axes=[1,2],name='Mre')
# z = dot([y,l],axes=-1,name='Mre')

# Build Model
model = Model(inputs=x,outputs=y)
model.summary()

# Build Aux Model
aux   = Model(inputs=x,outputs=[y,z])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 64, 64, 3)         0
# _________________________________________________________________
# E1 (Conv2D)                  (None, 32, 32, 64)        4864
# _________________________________________________________________
# E2 (Conv2D)                  (None, 16, 16, 50)        28850
# _________________________________________________________________
# E3 (Conv2D)                  (None, 8, 8, 32)          14432
# _________________________________________________________________
# E4 (Conv2D)                  (None, 8, 8, 50)          6450
# _________________________________________________________________
# D1 (Conv2D)                  (None, 8, 8, 50)          10050
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 50)        0
# _________________________________________________________________
# D2 (Conv2D)                  (None, 16, 16, 32)        14432
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# D3 (Conv2D)                  (None, 32, 32, 50)        14450
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 50)        0
# _________________________________________________________________
# D4 (Conv2D)                  (None, 64, 64, 1)         1251
# _________________________________________________________________
# Recon (Lambda)               (None, 64, 64)            0
# =================================================================
# Total params: 94,779
# Trainable params: 94,779
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling Model
model.compile(loss='mse',optimizer='adam')
aux.compile(loss='mse',loss_weights=[1.0,3.0],optimizer='adam')

# %%
x_aux = np.linalg.norm(x_train,axis=-1)

# %%
# Train Model
log = aux.fit(x_train,[y_train,x_aux],
             epochs=nepoch,
             batch_size=nbatch)

# log = model.fit(x_train,y_train,
#           epochs=nepoch,
#           batch_size=nbatch,
#           validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/200
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0659 - Recon_loss: 0.0470 - Mre_loss: 0.0063
# Epoch 2/200
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0543 - Recon_loss: 0.0425 - Mre_loss: 0.0039
# Epoch 3/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0496 - Recon_loss: 0.0376 - Mre_loss: 0.0040
# Epoch 4/200
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0476 - Recon_loss: 0.0356 - Mre_loss: 0.0040
# Epoch 5/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0469 - Recon_loss: 0.0342 - Mre_loss: 0.0042
# Epoch 6/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0447 - Recon_loss: 0.0325 - Mre_loss: 0.0041
# Epoch 7/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0432 - Recon_loss: 0.0306 - Mre_loss: 0.0042
# Epoch 8/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0427 - Recon_loss: 0.0296 - Mre_loss: 0.0044
# Epoch 9/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0408 - Recon_loss: 0.0282 - Mre_loss: 0.0042
# Epoch 10/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0391 - Recon_loss: 0.0269 - Mre_loss: 0.0041
# Epoch 11/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0379 - Recon_loss: 0.0250 - Mre_loss: 0.0043
# Epoch 12/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0378 - Recon_loss: 0.0259 - Mre_loss: 0.0039
# Epoch 13/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0377 - Recon_loss: 0.0251 - Mre_loss: 0.0042
# Epoch 14/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0370 - Recon_loss: 0.0250 - Mre_loss: 0.0040
# Epoch 15/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0359 - Recon_loss: 0.0238 - Mre_loss: 0.0040
# Epoch 16/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0363 - Recon_loss: 0.0240 - Mre_loss: 0.0041
# Epoch 17/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0354 - Recon_loss: 0.0235 - Mre_loss: 0.0040
# Epoch 18/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0345 - Recon_loss: 0.0228 - Mre_loss: 0.0039
# Epoch 19/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0348 - Recon_loss: 0.0229 - Mre_loss: 0.0040
# Epoch 20/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0347 - Recon_loss: 0.0223 - Mre_loss: 0.0041
# Epoch 21/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0343 - Recon_loss: 0.0228 - Mre_loss: 0.0038
# Epoch 22/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0339 - Recon_loss: 0.0222 - Mre_loss: 0.0039
# Epoch 23/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0332 - Recon_loss: 0.0214 - Mre_loss: 0.0039
# Epoch 24/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0331 - Recon_loss: 0.0215 - Mre_loss: 0.0039
# Epoch 25/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0325 - Recon_loss: 0.0208 - Mre_loss: 0.0039
# Epoch 26/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0323 - Recon_loss: 0.0207 - Mre_loss: 0.0039
# Epoch 27/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0322 - Recon_loss: 0.0206 - Mre_loss: 0.0038
# Epoch 28/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0323 - Recon_loss: 0.0209 - Mre_loss: 0.0038
# Epoch 29/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0318 - Recon_loss: 0.0201 - Mre_loss: 0.0039
# Epoch 30/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0321 - Recon_loss: 0.0205 - Mre_loss: 0.0039
# Epoch 31/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0315 - Recon_loss: 0.0200 - Mre_loss: 0.0038
# Epoch 32/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0308 - Recon_loss: 0.0195 - Mre_loss: 0.0038
# Epoch 33/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0307 - Recon_loss: 0.0192 - Mre_loss: 0.0038
# Epoch 34/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0305 - Recon_loss: 0.0190 - Mre_loss: 0.0038
# Epoch 35/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0303 - Recon_loss: 0.0191 - Mre_loss: 0.0037
# Epoch 36/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0299 - Recon_loss: 0.0189 - Mre_loss: 0.0037
# Epoch 37/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0296 - Recon_loss: 0.0184 - Mre_loss: 0.0037
# Epoch 38/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0297 - Recon_loss: 0.0184 - Mre_loss: 0.0038
# Epoch 39/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0291 - Recon_loss: 0.0182 - Mre_loss: 0.0036
# Epoch 40/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0292 - Recon_loss: 0.0184 - Mre_loss: 0.0036
# Epoch 41/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0288 - Recon_loss: 0.0179 - Mre_loss: 0.0036
# Epoch 42/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0286 - Recon_loss: 0.0178 - Mre_loss: 0.0036
# Epoch 43/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0285 - Recon_loss: 0.0176 - Mre_loss: 0.0036
# Epoch 44/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0280 - Recon_loss: 0.0174 - Mre_loss: 0.0035
# Epoch 45/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0279 - Recon_loss: 0.0171 - Mre_loss: 0.0036
# Epoch 46/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0278 - Recon_loss: 0.0171 - Mre_loss: 0.0036
# Epoch 47/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0280 - Recon_loss: 0.0175 - Mre_loss: 0.0035
# Epoch 48/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0279 - Recon_loss: 0.0172 - Mre_loss: 0.0036
# Epoch 49/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0273 - Recon_loss: 0.0168 - Mre_loss: 0.0035
# Epoch 50/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0272 - Recon_loss: 0.0167 - Mre_loss: 0.0035
# Epoch 51/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0270 - Recon_loss: 0.0165 - Mre_loss: 0.0035
# Epoch 52/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0268 - Recon_loss: 0.0165 - Mre_loss: 0.0035
# Epoch 53/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0268 - Recon_loss: 0.0165 - Mre_loss: 0.0034
# Epoch 54/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0267 - Recon_loss: 0.0162 - Mre_loss: 0.0035
# Epoch 55/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0268 - Recon_loss: 0.0166 - Mre_loss: 0.0034
# Epoch 56/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0269 - Recon_loss: 0.0165 - Mre_loss: 0.0035
# Epoch 57/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0266 - Recon_loss: 0.0164 - Mre_loss: 0.0034
# Epoch 58/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0263 - Recon_loss: 0.0160 - Mre_loss: 0.0034
# Epoch 59/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0260 - Recon_loss: 0.0158 - Mre_loss: 0.0034
# Epoch 60/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0258 - Recon_loss: 0.0157 - Mre_loss: 0.0034
# Epoch 61/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0259 - Recon_loss: 0.0157 - Mre_loss: 0.0034
# Epoch 62/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0259 - Recon_loss: 0.0157 - Mre_loss: 0.0034
# Epoch 63/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0257 - Recon_loss: 0.0156 - Mre_loss: 0.0034
# Epoch 64/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0257 - Recon_loss: 0.0156 - Mre_loss: 0.0034
# Epoch 65/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0255 - Recon_loss: 0.0154 - Mre_loss: 0.0033
# Epoch 66/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0255 - Recon_loss: 0.0155 - Mre_loss: 0.0033
# Epoch 67/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0256 - Recon_loss: 0.0156 - Mre_loss: 0.0033
# Epoch 68/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0255 - Recon_loss: 0.0156 - Mre_loss: 0.0033
# Epoch 69/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0256 - Recon_loss: 0.0156 - Mre_loss: 0.0033
# Epoch 70/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0255 - Recon_loss: 0.0154 - Mre_loss: 0.0034
# Epoch 71/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0253 - Recon_loss: 0.0154 - Mre_loss: 0.0033
# Epoch 72/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0253 - Recon_loss: 0.0150 - Mre_loss: 0.0034
# Epoch 73/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0254 - Recon_loss: 0.0155 - Mre_loss: 0.0033
# Epoch 74/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0251 - Recon_loss: 0.0153 - Mre_loss: 0.0033
# Epoch 75/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0249 - Recon_loss: 0.0149 - Mre_loss: 0.0033
# Epoch 76/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0247 - Recon_loss: 0.0149 - Mre_loss: 0.0033
# Epoch 77/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0248 - Recon_loss: 0.0149 - Mre_loss: 0.0033
# Epoch 78/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0245 - Recon_loss: 0.0148 - Mre_loss: 0.0032
# Epoch 79/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0245 - Recon_loss: 0.0146 - Mre_loss: 0.0033
# Epoch 80/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0248 - Recon_loss: 0.0151 - Mre_loss: 0.0032
# Epoch 81/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0244 - Recon_loss: 0.0147 - Mre_loss: 0.0033
# Epoch 82/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0244 - Recon_loss: 0.0146 - Mre_loss: 0.0033
# Epoch 83/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0247 - Recon_loss: 0.0147 - Mre_loss: 0.0033
# Epoch 84/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0247 - Recon_loss: 0.0149 - Mre_loss: 0.0033
# Epoch 85/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0244 - Recon_loss: 0.0146 - Mre_loss: 0.0033
# Epoch 86/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0247 - Recon_loss: 0.0149 - Mre_loss: 0.0033
# Epoch 87/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0251 - Recon_loss: 0.0151 - Mre_loss: 0.0033
# Epoch 88/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0253 - Recon_loss: 0.0154 - Mre_loss: 0.0033
# Epoch 89/200
# 299/299 [==============================] - 8s 25ms/step - loss: 0.0246 - Recon_loss: 0.0147 - Mre_loss: 0.0033
# Epoch 90/200
# 299/299 [==============================] - 1124s 4s/step - loss: 0.0245 - Recon_loss: 0.0147 - Mre_loss: 0.0033
# Epoch 91/200
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0243 - Recon_loss: 0.0146 - Mre_loss: 0.0032
# Epoch 92/200
# 299/299 [==============================] - 19s 63ms/step - loss: 0.0243 - Recon_loss: 0.0146 - Mre_loss: 0.0032
# Epoch 93/200
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0240 - Recon_loss: 0.0144 - Mre_loss: 0.0032
# Epoch 94/200
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0238 - Recon_loss: 0.0141 - Mre_loss: 0.0032
# Epoch 95/200
# 299/299 [==============================] - 2344s 8s/step - loss: 0.0237 - Recon_loss: 0.0141 - Mre_loss: 0.0032
# Epoch 96/200
# 299/299 [==============================] - 18s 59ms/step - loss: 0.0238 - Recon_loss: 0.0142 - Mre_loss: 0.0032
# Epoch 97/200
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0237 - Recon_loss: 0.0141 - Mre_loss: 0.0032
# Epoch 98/200
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0235 - Recon_loss: 0.0139 - Mre_loss: 0.0032
# Epoch 99/200
# 299/299 [==============================] - 16s 55ms/step - loss: 0.0239 - Recon_loss: 0.0143 - Mre_loss: 0.0032
# Epoch 100/200
# 299/299 [==============================] - 13s 44ms/step - loss: 0.0238 - Recon_loss: 0.0141 - Mre_loss: 0.0032
# Epoch 101/200
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0236 - Recon_loss: 0.0141 - Mre_loss: 0.0032
# Epoch 102/200
# 299/299 [==============================] - 2190s 7s/step - loss: 0.0235 - Recon_loss: 0.0139 - Mre_loss: 0.0032
# Epoch 103/200
# 299/299 [==============================] - 7s 23ms/step - loss: 0.0236 - Recon_loss: 0.0140 - Mre_loss: 0.0032
# Epoch 104/200
# 299/299 [==============================] - 18s 61ms/step - loss: 0.0234 - Recon_loss: 0.0139 - Mre_loss: 0.0032
# Epoch 105/200
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0233 - Recon_loss: 0.0139 - Mre_loss: 0.0032
# Epoch 106/200
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0232 - Recon_loss: 0.0138 - Mre_loss: 0.0032
# Epoch 107/200
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0232 - Recon_loss: 0.0137 - Mre_loss: 0.0032
# Epoch 108/200
# 299/299 [==============================] - 1402s 5s/step - loss: 0.0232 - Recon_loss: 0.0137 - Mre_loss: 0.0032
# Epoch 109/200
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0232 - Recon_loss: 0.0137 - Mre_loss: 0.0032
# Epoch 110/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0233 - Recon_loss: 0.0138 - Mre_loss: 0.0032
# Epoch 111/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0235 - Recon_loss: 0.0140 - Mre_loss: 0.0032
# Epoch 112/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0234 - Recon_loss: 0.0139 - Mre_loss: 0.0032
# Epoch 113/200
# 299/299 [==============================] - 8s 25ms/step - loss: 0.0232 - Recon_loss: 0.0138 - Mre_loss: 0.0031
# Epoch 114/200
# 299/299 [==============================] - 500s 2s/step - loss: 0.0235 - Recon_loss: 0.0139 - Mre_loss: 0.0032
# Epoch 115/200
# 299/299 [==============================] - 16s 55ms/step - loss: 0.0233 - Recon_loss: 0.0138 - Mre_loss: 0.0032
# Epoch 116/200
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0235 - Recon_loss: 0.0140 - Mre_loss: 0.0032
# Epoch 117/200
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0235 - Recon_loss: 0.0139 - Mre_loss: 0.0032
# Epoch 118/200
# 299/299 [==============================] - 29s 97ms/step - loss: 0.0235 - Recon_loss: 0.0137 - Mre_loss: 0.0032
# Epoch 119/200
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0236 - Recon_loss: 0.0141 - Mre_loss: 0.0032
# Epoch 120/200
# 299/299 [==============================] - 19s 62ms/step - loss: 0.0235 - Recon_loss: 0.0138 - Mre_loss: 0.0032
# Epoch 121/200
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0231 - Recon_loss: 0.0137 - Mre_loss: 0.0031
# Epoch 122/200
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0231 - Recon_loss: 0.0135 - Mre_loss: 0.0032
# Epoch 123/200
# 299/299 [==============================] - 202s 677ms/step - loss: 0.0233 - Recon_loss: 0.0141 - Mre_loss: 0.0031
# Epoch 124/200
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0232 - Recon_loss: 0.0136 - Mre_loss: 0.0032
# Epoch 125/200
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0230 - Recon_loss: 0.0137 - Mre_loss: 0.0031
# Epoch 126/200
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0227 - Recon_loss: 0.0134 - Mre_loss: 0.0031
# Epoch 127/200
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0227 - Recon_loss: 0.0134 - Mre_loss: 0.0031
# Epoch 128/200
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0227 - Recon_loss: 0.0133 - Mre_loss: 0.0031
# Epoch 129/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0226 - Recon_loss: 0.0132 - Mre_loss: 0.0031
# Epoch 130/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0230 - Recon_loss: 0.0137 - Mre_loss: 0.0031
# Epoch 131/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0229 - Recon_loss: 0.0135 - Mre_loss: 0.0031
# Epoch 132/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0232 - Recon_loss: 0.0138 - Mre_loss: 0.0031
# Epoch 133/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0228 - Recon_loss: 0.0134 - Mre_loss: 0.0031
# Epoch 134/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0226 - Recon_loss: 0.0133 - Mre_loss: 0.0031
# Epoch 135/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0225 - Recon_loss: 0.0133 - Mre_loss: 0.0031
# Epoch 136/200
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0224 - Recon_loss: 0.0132 - Mre_loss: 0.0031
# Epoch 137/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0223 - Recon_loss: 0.0131 - Mre_loss: 0.0031
# Epoch 138/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0222 - Recon_loss: 0.0130 - Mre_loss: 0.0031
# Epoch 139/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0222 - Recon_loss: 0.0130 - Mre_loss: 0.0030
# Epoch 140/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0222 - Recon_loss: 0.0131 - Mre_loss: 0.0030
# Epoch 141/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0224 - Recon_loss: 0.0131 - Mre_loss: 0.0031
# Epoch 142/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0223 - Recon_loss: 0.0131 - Mre_loss: 0.0031
# Epoch 143/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0223 - Recon_loss: 0.0131 - Mre_loss: 0.0031
# Epoch 144/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0222 - Recon_loss: 0.0130 - Mre_loss: 0.0031
# Epoch 145/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0222 - Recon_loss: 0.0130 - Mre_loss: 0.0031
# Epoch 146/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0221 - Recon_loss: 0.0130 - Mre_loss: 0.0030
# Epoch 147/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0222 - Recon_loss: 0.0129 - Mre_loss: 0.0031
# Epoch 148/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0222 - Recon_loss: 0.0130 - Mre_loss: 0.0031
# Epoch 149/200
# 299/299 [==============================] - 9s 28ms/step - loss: 0.0222 - Recon_loss: 0.0129 - Mre_loss: 0.0031
# Epoch 150/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0223 - Recon_loss: 0.0132 - Mre_loss: 0.0030
# Epoch 151/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0225 - Recon_loss: 0.0132 - Mre_loss: 0.0031
# Epoch 152/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0222 - Recon_loss: 0.0131 - Mre_loss: 0.0030
# Epoch 153/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0220 - Recon_loss: 0.0129 - Mre_loss: 0.0030
# Epoch 154/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0220 - Recon_loss: 0.0129 - Mre_loss: 0.0031
# Epoch 155/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0220 - Recon_loss: 0.0129 - Mre_loss: 0.0030
# Epoch 156/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0220 - Recon_loss: 0.0130 - Mre_loss: 0.0030
# Epoch 157/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0220 - Recon_loss: 0.0128 - Mre_loss: 0.0030
# Epoch 158/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0220 - Recon_loss: 0.0129 - Mre_loss: 0.0030
# Epoch 159/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0219 - Recon_loss: 0.0129 - Mre_loss: 0.0030
# Epoch 160/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0218 - Recon_loss: 0.0128 - Mre_loss: 0.0030
# Epoch 161/200
# 299/299 [==============================] - 9s 28ms/step - loss: 0.0221 - Recon_loss: 0.0130 - Mre_loss: 0.0030
# Epoch 162/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0219 - Recon_loss: 0.0128 - Mre_loss: 0.0030
# Epoch 163/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0217 - Recon_loss: 0.0126 - Mre_loss: 0.0030
# Epoch 164/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0216 - Recon_loss: 0.0126 - Mre_loss: 0.0030
# Epoch 165/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0220 - Recon_loss: 0.0129 - Mre_loss: 0.0030
# Epoch 166/200
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0219 - Recon_loss: 0.0128 - Mre_loss: 0.0030
# Epoch 167/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0218 - Recon_loss: 0.0128 - Mre_loss: 0.0030
# Epoch 168/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0217 - Recon_loss: 0.0128 - Mre_loss: 0.0030
# Epoch 169/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0216 - Recon_loss: 0.0126 - Mre_loss: 0.0030
# Epoch 170/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0216 - Recon_loss: 0.0127 - Mre_loss: 0.0030
# Epoch 171/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0216 - Recon_loss: 0.0126 - Mre_loss: 0.0030
# Epoch 172/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0215 - Recon_loss: 0.0126 - Mre_loss: 0.0030
# Epoch 173/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0216 - Recon_loss: 0.0127 - Mre_loss: 0.0029
# Epoch 174/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0215 - Recon_loss: 0.0125 - Mre_loss: 0.0030
# Epoch 175/200
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0213 - Recon_loss: 0.0125 - Mre_loss: 0.0029
# Epoch 176/200
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0213 - Recon_loss: 0.0124 - Mre_loss: 0.0030
# Epoch 177/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0213 - Recon_loss: 0.0124 - Mre_loss: 0.0030
# Epoch 178/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0214 - Recon_loss: 0.0126 - Mre_loss: 0.0029
# Epoch 179/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0214 - Recon_loss: 0.0124 - Mre_loss: 0.0030
# Epoch 180/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0216 - Recon_loss: 0.0127 - Mre_loss: 0.0030
# Epoch 181/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0218 - Recon_loss: 0.0125 - Mre_loss: 0.0031
# Epoch 182/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0221 - Recon_loss: 0.0132 - Mre_loss: 0.0030
# Epoch 183/200
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0220 - Recon_loss: 0.0129 - Mre_loss: 0.0030
# Epoch 184/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0216 - Recon_loss: 0.0127 - Mre_loss: 0.0030
# Epoch 185/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0216 - Recon_loss: 0.0127 - Mre_loss: 0.0030
# Epoch 186/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0216 - Recon_loss: 0.0126 - Mre_loss: 0.0030
# Epoch 187/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0214 - Recon_loss: 0.0125 - Mre_loss: 0.0030
# Epoch 188/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0212 - Recon_loss: 0.0124 - Mre_loss: 0.0029
# Epoch 189/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0213 - Recon_loss: 0.0125 - Mre_loss: 0.0029
# Epoch 190/200
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0213 - Recon_loss: 0.0125 - Mre_loss: 0.0029
# Epoch 191/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0213 - Recon_loss: 0.0124 - Mre_loss: 0.0030
# Epoch 192/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0214 - Recon_loss: 0.0126 - Mre_loss: 0.0029
# Epoch 193/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0213 - Recon_loss: 0.0124 - Mre_loss: 0.0030
# Epoch 194/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0212 - Recon_loss: 0.0124 - Mre_loss: 0.0029
# Epoch 195/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0211 - Recon_loss: 0.0123 - Mre_loss: 0.0029
# Epoch 196/200
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0212 - Recon_loss: 0.0123 - Mre_loss: 0.0030
# Epoch 197/200
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0211 - Recon_loss: 0.0123 - Mre_loss: 0.0029
# Epoch 198/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0211 - Recon_loss: 0.0123 - Mre_loss: 0.0029
# Epoch 199/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0211 - Recon_loss: 0.0124 - Mre_loss: 0.0029
# Epoch 200/200
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0213 - Recon_loss: 0.0124 - Mre_loss: 0.0030

# %%
# Plot Loss Curves
mloss = log.history['Mre_loss']
rloss = log.history['Recon_loss']
nepch = log.epoch

plt.figure(figsize=(8,3))
plt.subplot(121), plt.plot(nepch,rloss),plt.title('Recon Loss')
plt.subplot(122), plt.plot(nepch,mloss,'g'),plt.title('Mre Loss')
plt.tight_layout()

# %% [markdown]
# ## Model Evaluation

# %%
# Generate Predictions
y_pred = model.predict(x_test)

# %%
# Visualize Examples
N   = 5
row = 2
col = N

sidx = random.sample(range(len(y_pred)),N)

fig,axs = plt.subplots(row,col,sharex='col',sharey='row',figsize=(14,6))
for i,n in enumerate(sidx):
    axs[0,i%col].imshow(y_test[n])
    axs[1,i%col].imshow(y_pred[n])
    
    mse = mean_squared_error(y_pred[n],y_test[n])
    header = '{0}, mse={1:.04f}'.format(n,mse)
    axs[0,i%col].set_title(header)
