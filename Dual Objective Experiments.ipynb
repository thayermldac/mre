# %%
# %matplotlib inline 

# Basics
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# Keras
import keras
import keras.backend as K
from keras.models import Model, load_model
from keras.layers import Input, Dense, Conv2D, Lambda, UpSampling2D
from keras.layers import Dot, dot

# Others
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
# Load Dataset
df=pd.read_msgpack('MREdata_072118.msg')

# %%
# Prepare Data
Ur = np.stack(df.Ur.values,axis=3).transpose(3,0,1,2)
Ui = np.stack(df.Ui.values,axis=3).transpose(3,0,1,2)
x_data = np.sqrt(Ui**2+Ur**2)

y_data = np.stack(df.RS.values,axis=2).transpose(2,0,1)
y_data = y_data/10000.

print 'X size:', x_data.shape
print 'Y size:', y_data.shape
# Out:
# X size: (612, 64, 64, 3)
# Y size: (612, 64, 64)

# %%
# Split to Train & Valid
x_train, x_test, y_train, y_test = train_test_split(x_data,y_data,test_size=0.3)
x_train, x_valid, y_train, y_valid = train_test_split(x_train,y_train,test_size=0.3)

print 'Training examples:   ', len(x_train)
print 'Validation examples: ', len(x_valid)
print 'Testing examples:    ', len(x_test)
# Out:
# Training examples:    299
# Validation examples:  129
# Testing examples:     184

# %% [markdown]
# ### Building Neural Network

# %%
def laplace(x):
    # Make Kernel
    a = np.asarray([[0., 1., 0.],
                    [1.,-4., 1.],
                    [0., 1., 0.]])    
#     a = np.asarray([[0.5, 1.0, 0.5],
#                     [1.0, -6., 1.0],
#                     [0.5, 1.0, 0.5]])
    a = a.reshape(list(a.shape) + [1,1])
    kernel = K.constant(a,dtype=1)
    
    # Do Convolution
    x = K.expand_dims(K.expand_dims(x, 0), -1)
    y = K.depthwise_conv2d(x,kernel, padding='same')
    
    return y[0,:,:,0]

def laplacian(x):
    u = K.tf.norm(x,axis=3)
    return K.map_fn(laplace,u)

# %%
# Parameters
xshp   = x_train.shape[1:]
nbatch = 16
nepoch = 100

# Architecture
L1 = 64
L2 = 50
L3 = 32
L4 = 32

# %%
# Build Neural Model

# Encoding
x  = Input(shape=xshp,name='Input')
h  = Conv2D(L1,kernel_size=(5,5),strides=(2,2),activation='relu',padding='same',name='E1')(x)
h  = Conv2D(L2,kernel_size=(3,3),strides=(2,2),activation='relu',padding='same',name='E2')(h)
h  = Conv2D(L3,kernel_size=(3,3),strides=(2,2),activation='relu',padding='same',name='E3')(h)
e  = Conv2D(L4,kernel_size=(2,2),strides=(1,1),activation='relu',padding='same',name='E4')(h)

# Decoding
h  = Conv2D(L4,kernel_size=(2,2),activation='relu',padding='same',name='D1')(e)
h  = UpSampling2D((2,2))(h)
h  = Conv2D(L3,kernel_size=(3,3),activation='relu',padding='same',name='D2')(h)
h  = UpSampling2D((2,2))(h)
h  = Conv2D(L2,kernel_size=(3,3),activation='relu',padding='same',name='D3')(h)
h  = UpSampling2D((2,2))(h)
h  = Conv2D(1,kernel_size=(5,5),activation='relu',padding='same',name='D4')(h)
y  = Lambda(lambda xx: K.squeeze(xx,3),name='Recon')(h)

# Laplacian
l = Lambda(laplacian,name='Laplacian')(x)
z = dot([y,l],axes=[1,2],name='Mre')
# z = dot([y,l],axes=-1,name='Mre')

# Build Model
model = Model(inputs=x,outputs=y)
model.summary()

# Build Aux Model
aux   = Model(inputs=x,outputs=[y,z])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 64, 64, 3)         0
# _________________________________________________________________
# E1 (Conv2D)                  (None, 32, 32, 64)        4864
# _________________________________________________________________
# E2 (Conv2D)                  (None, 16, 16, 50)        28850
# _________________________________________________________________
# E3 (Conv2D)                  (None, 8, 8, 32)          14432
# _________________________________________________________________
# E4 (Conv2D)                  (None, 8, 8, 32)          4128
# _________________________________________________________________
# D1 (Conv2D)                  (None, 8, 8, 32)          4128
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# D2 (Conv2D)                  (None, 16, 16, 32)        9248
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# D3 (Conv2D)                  (None, 32, 32, 50)        14450
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 50)        0
# _________________________________________________________________
# D4 (Conv2D)                  (None, 64, 64, 1)         1251
# _________________________________________________________________
# Recon (Lambda)               (None, 64, 64)            0
# =================================================================
# Total params: 81,351
# Trainable params: 81,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling Model
model.compile(loss='mse',optimizer='adam')
aux.compile(loss='mse',  optimizer='adam')

# %%
x_aux = np.linalg.norm(x_train,axis=-1)

# %%
# Train Model
log = aux.fit(x_train,[y_train,x_aux],
             epochs=nepoch,
             batch_size=nbatch)

# log = model.fit(x_train,y_train,
#           epochs=nepoch,
#           batch_size=nbatch,
#           validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0477 - Recon_loss: 0.0408 - Mre_loss: 0.0070
# Epoch 2/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0397 - Recon_loss: 0.0330 - Mre_loss: 0.0066
# Epoch 3/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0378 - Recon_loss: 0.0311 - Mre_loss: 0.0067
# Epoch 4/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0344 - Recon_loss: 0.0273 - Mre_loss: 0.0071
# Epoch 5/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0315 - Recon_loss: 0.0246 - Mre_loss: 0.0069
# Epoch 6/100
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0308 - Recon_loss: 0.0230 - Mre_loss: 0.0078
# Epoch 7/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0298 - Recon_loss: 0.0227 - Mre_loss: 0.0071
# Epoch 8/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0290 - Recon_loss: 0.0218 - Mre_loss: 0.0072
# Epoch 9/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0276 - Recon_loss: 0.0201 - Mre_loss: 0.0074
# Epoch 10/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0268 - Recon_loss: 0.0191 - Mre_loss: 0.0078
# Epoch 11/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0270 - Recon_loss: 0.0201 - Mre_loss: 0.0069
# Epoch 12/100
# 299/299 [==============================] - 15s 49ms/step - loss: 0.0266 - Recon_loss: 0.0191 - Mre_loss: 0.0074
# Epoch 13/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0258 - Recon_loss: 0.0182 - Mre_loss: 0.0076
# Epoch 14/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0252 - Recon_loss: 0.0178 - Mre_loss: 0.0074
# Epoch 15/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0246 - Recon_loss: 0.0174 - Mre_loss: 0.0073
# Epoch 16/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0244 - Recon_loss: 0.0171 - Mre_loss: 0.0073
# Epoch 17/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0239 - Recon_loss: 0.0169 - Mre_loss: 0.0070
# Epoch 18/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0236 - Recon_loss: 0.0162 - Mre_loss: 0.0074
# Epoch 19/100
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0232 - Recon_loss: 0.0158 - Mre_loss: 0.0074
# Epoch 20/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0235 - Recon_loss: 0.0162 - Mre_loss: 0.0073
# Epoch 21/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0227 - Recon_loss: 0.0154 - Mre_loss: 0.0072
# Epoch 22/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0228 - Recon_loss: 0.0156 - Mre_loss: 0.0072
# Epoch 23/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0226 - Recon_loss: 0.0153 - Mre_loss: 0.0073
# Epoch 24/100
# 299/299 [==============================] - 13s 42ms/step - loss: 0.0217 - Recon_loss: 0.0145 - Mre_loss: 0.0072
# Epoch 25/100
# 299/299 [==============================] - 17s 56ms/step - loss: 0.0215 - Recon_loss: 0.0143 - Mre_loss: 0.0072
# Epoch 26/100
# 299/299 [==============================] - 14s 46ms/step - loss: 0.0213 - Recon_loss: 0.0141 - Mre_loss: 0.0072
# Epoch 27/100
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0212 - Recon_loss: 0.0143 - Mre_loss: 0.0069
# Epoch 28/100
# 299/299 [==============================] - 14s 46ms/step - loss: 0.0208 - Recon_loss: 0.0136 - Mre_loss: 0.0072
# Epoch 29/100
# 299/299 [==============================] - 22s 72ms/step - loss: 0.0203 - Recon_loss: 0.0132 - Mre_loss: 0.0071
# Epoch 30/100
# 299/299 [==============================] - 15s 49ms/step - loss: 0.0203 - Recon_loss: 0.0132 - Mre_loss: 0.0071
# Epoch 31/100
# 299/299 [==============================] - 15s 50ms/step - loss: 0.0202 - Recon_loss: 0.0133 - Mre_loss: 0.0069
# Epoch 32/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0202 - Recon_loss: 0.0132 - Mre_loss: 0.0070
# Epoch 33/100
# 299/299 [==============================] - 13s 42ms/step - loss: 0.0196 - Recon_loss: 0.0126 - Mre_loss: 0.0070
# Epoch 34/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0196 - Recon_loss: 0.0127 - Mre_loss: 0.0070
# Epoch 35/100
# 299/299 [==============================] - 11s 35ms/step - loss: 0.0205 - Recon_loss: 0.0137 - Mre_loss: 0.0069
# Epoch 36/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0203 - Recon_loss: 0.0130 - Mre_loss: 0.0072
# Epoch 37/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0194 - Recon_loss: 0.0123 - Mre_loss: 0.0070
# Epoch 38/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0191 - Recon_loss: 0.0122 - Mre_loss: 0.0069
# Epoch 39/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0190 - Recon_loss: 0.0121 - Mre_loss: 0.0070
# Epoch 40/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0188 - Recon_loss: 0.0118 - Mre_loss: 0.0069
# Epoch 41/100
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0187 - Recon_loss: 0.0118 - Mre_loss: 0.0069
# Epoch 42/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0185 - Recon_loss: 0.0116 - Mre_loss: 0.0070
# Epoch 43/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0184 - Recon_loss: 0.0116 - Mre_loss: 0.0069
# Epoch 44/100
# 299/299 [==============================] - 11s 35ms/step - loss: 0.0184 - Recon_loss: 0.0115 - Mre_loss: 0.0069
# Epoch 45/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0182 - Recon_loss: 0.0114 - Mre_loss: 0.0068
# Epoch 46/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0181 - Recon_loss: 0.0113 - Mre_loss: 0.0069
# Epoch 47/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0180 - Recon_loss: 0.0112 - Mre_loss: 0.0068
# Epoch 48/100
# 299/299 [==============================] - 9s 32ms/step - loss: 0.0180 - Recon_loss: 0.0110 - Mre_loss: 0.0069
# Epoch 49/100
# 299/299 [==============================] - 9s 32ms/step - loss: 0.0181 - Recon_loss: 0.0114 - Mre_loss: 0.0067
# Epoch 50/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0178 - Recon_loss: 0.0110 - Mre_loss: 0.0068
# Epoch 51/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0179 - Recon_loss: 0.0112 - Mre_loss: 0.0068
# Epoch 52/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0178 - Recon_loss: 0.0111 - Mre_loss: 0.0067
# Epoch 53/100
# 299/299 [==============================] - 14s 48ms/step - loss: 0.0176 - Recon_loss: 0.0107 - Mre_loss: 0.0068
# Epoch 54/100
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0174 - Recon_loss: 0.0107 - Mre_loss: 0.0067
# Epoch 55/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0175 - Recon_loss: 0.0107 - Mre_loss: 0.0068
# Epoch 56/100
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0174 - Recon_loss: 0.0107 - Mre_loss: 0.0067
# Epoch 57/100
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0171 - Recon_loss: 0.0105 - Mre_loss: 0.0067
# Epoch 58/100
# 299/299 [==============================] - 8s 28ms/step - loss: 0.0173 - Recon_loss: 0.0106 - Mre_loss: 0.0067
# Epoch 59/100
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0173 - Recon_loss: 0.0106 - Mre_loss: 0.0067
# Epoch 60/100
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0171 - Recon_loss: 0.0104 - Mre_loss: 0.0067
# Epoch 61/100
# 299/299 [==============================] - 14s 46ms/step - loss: 0.0170 - Recon_loss: 0.0103 - Mre_loss: 0.0067
# Epoch 62/100
# 299/299 [==============================] - 16s 52ms/step - loss: 0.0170 - Recon_loss: 0.0103 - Mre_loss: 0.0067
# Epoch 63/100
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0169 - Recon_loss: 0.0102 - Mre_loss: 0.0067
# Epoch 64/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0174 - Recon_loss: 0.0106 - Mre_loss: 0.0068
# Epoch 65/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0173 - Recon_loss: 0.0107 - Mre_loss: 0.0066
# Epoch 66/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0171 - Recon_loss: 0.0104 - Mre_loss: 0.0067
# Epoch 67/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0168 - Recon_loss: 0.0102 - Mre_loss: 0.0066
# Epoch 68/100
# 299/299 [==============================] - 15s 52ms/step - loss: 0.0167 - Recon_loss: 0.0100 - Mre_loss: 0.0067
# Epoch 69/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0166 - Recon_loss: 0.0100 - Mre_loss: 0.0065
# Epoch 70/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0164 - Recon_loss: 0.0097 - Mre_loss: 0.0067
# Epoch 71/100
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0167 - Recon_loss: 0.0102 - Mre_loss: 0.0065
# Epoch 72/100
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0170 - Recon_loss: 0.0103 - Mre_loss: 0.0066
# Epoch 73/100
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0167 - Recon_loss: 0.0100 - Mre_loss: 0.0067
# Epoch 74/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0167 - Recon_loss: 0.0102 - Mre_loss: 0.0065
# Epoch 75/100
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0164 - Recon_loss: 0.0098 - Mre_loss: 0.0066
# Epoch 76/100
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0163 - Recon_loss: 0.0097 - Mre_loss: 0.0066
# Epoch 77/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0162 - Recon_loss: 0.0096 - Mre_loss: 0.0066
# Epoch 78/100
# 299/299 [==============================] - 13s 42ms/step - loss: 0.0161 - Recon_loss: 0.0097 - Mre_loss: 0.0064
# Epoch 79/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0161 - Recon_loss: 0.0095 - Mre_loss: 0.0066
# Epoch 80/100
# 299/299 [==============================] - 16s 52ms/step - loss: 0.0160 - Recon_loss: 0.0095 - Mre_loss: 0.0066
# Epoch 81/100
# 299/299 [==============================] - 12s 41ms/step - loss: 0.0160 - Recon_loss: 0.0094 - Mre_loss: 0.0066
# Epoch 82/100
# 299/299 [==============================] - 12s 39ms/step - loss: 0.0159 - Recon_loss: 0.0094 - Mre_loss: 0.0065
# Epoch 83/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0159 - Recon_loss: 0.0094 - Mre_loss: 0.0065
# Epoch 84/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0158 - Recon_loss: 0.0093 - Mre_loss: 0.0065
# Epoch 85/100
# 299/299 [==============================] - 13s 43ms/step - loss: 0.0158 - Recon_loss: 0.0092 - Mre_loss: 0.0066
# Epoch 86/100
# 299/299 [==============================] - 12s 42ms/step - loss: 0.0159 - Recon_loss: 0.0095 - Mre_loss: 0.0064
# Epoch 87/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0159 - Recon_loss: 0.0093 - Mre_loss: 0.0066
# Epoch 88/100
# 299/299 [==============================] - 12s 40ms/step - loss: 0.0158 - Recon_loss: 0.0093 - Mre_loss: 0.0065
# Epoch 89/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0158 - Recon_loss: 0.0093 - Mre_loss: 0.0065
# Epoch 90/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0159 - Recon_loss: 0.0094 - Mre_loss: 0.0065
# Epoch 91/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0157 - Recon_loss: 0.0093 - Mre_loss: 0.0065
# Epoch 92/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0157 - Recon_loss: 0.0092 - Mre_loss: 0.0065
# Epoch 93/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0157 - Recon_loss: 0.0092 - Mre_loss: 0.0065
# Epoch 94/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0156 - Recon_loss: 0.0092 - Mre_loss: 0.0064
# Epoch 95/100
# 299/299 [==============================] - 8s 27ms/step - loss: 0.0155 - Recon_loss: 0.0090 - Mre_loss: 0.0065
# Epoch 96/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0154 - Recon_loss: 0.0091 - Mre_loss: 0.0064
# Epoch 97/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0154 - Recon_loss: 0.0090 - Mre_loss: 0.0065
# Epoch 98/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0154 - Recon_loss: 0.0089 - Mre_loss: 0.0064
# Epoch 99/100
# 299/299 [==============================] - 8s 26ms/step - loss: 0.0154 - Recon_loss: 0.0089 - Mre_loss: 0.0065
# Epoch 100/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0156 - Recon_loss: 0.0092 - Mre_loss: 0.0064

# %% [markdown]
# ## Model Evaluation

# %%
# Generate Predictions
y_pred = model.predict(x_test)

# %%
# Visualize Examples
N   = 5
row = 2
col = N

sidx = random.sample(range(len(y_pred)),N)

fig,axs = plt.subplots(row,col,sharex='col',sharey='row',figsize=(14,6))
for i,n in enumerate(sidx):
    axs[0,i%col].imshow(y_test[n])
    axs[1,i%col].imshow(y_pred[n])
    
    mse = mean_squared_error(y_pred[n],y_test[n])
    header = '{0}, mse={1:.04f}'.format(n,mse)
    axs[0,i%col].set_title(header)
