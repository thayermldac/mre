# %%
# %matplotlib inline 

# Basics
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# Keras
import keras
import keras.backend as K
from keras.models import Model, load_model
from keras.layers import Input, Dense, Conv2D, Lambda, UpSampling2D
from keras.layers import Dot, dot, Dropout, BatchNormalization

# Others
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
# Load Dataset
df=pd.read_msgpack('MREdata_072118.msg')

# %%
# Prepare Data
Ur = np.stack(df.Ur.values,axis=3).transpose(3,0,1,2)
Ui = np.stack(df.Ui.values,axis=3).transpose(3,0,1,2)
x_data = np.sqrt(Ui**2+Ur**2)

y_data = np.stack(df.RS.values,axis=2).transpose(2,0,1)
y_data = y_data/10000.

print 'X size:', x_data.shape
print 'Y size:', y_data.shape
# Out:
# X size: (612, 64, 64, 3)
# Y size: (612, 64, 64)

# %%
# Split to Train & Valid
x_train, x_test, y_train, y_test = train_test_split(x_data,y_data,test_size=0.3)
x_train, x_valid, y_train, y_valid = train_test_split(x_train,y_train,test_size=0.3)

print 'Training examples:   ', len(x_train)
print 'Validation examples: ', len(x_valid)
print 'Testing examples:    ', len(x_test)
# Out:
# Training examples:    299
# Validation examples:  129
# Testing examples:     184

# %% [markdown]
# ### Building Neural Network

# %%
def laplace(x):
    # Make Kernel
    a = np.asarray([[0., 1., 0.],
                    [1.,-4., 1.],
                    [0., 1., 0.]])    
#     a = np.asarray([[0.5, 1.0, 0.5],
#                     [1.0, -6., 1.0],
#                     [0.5, 1.0, 0.5]])
    a = a.reshape(list(a.shape) + [1,1])
    kernel = K.constant(a,dtype=1)
    
    # Do Convolution
    x = K.expand_dims(K.expand_dims(x, 0), -1)
    y = K.depthwise_conv2d(x,kernel, padding='same')
    
    return y[0,:,:,0]

def laplacian(x):
    u = K.tf.norm(x,axis=3)
    return K.map_fn(laplace,u)

# %%
# Parameters
xshp   = x_train.shape[1:]
nbatch = 16
nepoch = 100

# Architecture
L1 = 64
L2 = 50
L3 = 32
L4 = 32

# %%
# Build Neural Model

# Encoding
x  = Input(shape=xshp,name='Input')
h  = Conv2D(L1,kernel_size=(5,5),strides=(2,2),activation='relu',padding='same',name='E1')(x)
h  = BatchNormalization()(h)
h  = Conv2D(L2,kernel_size=(3,3),strides=(2,2),activation='relu',padding='same',name='E2')(h)
h  = BatchNormalization()(h)
h  = Conv2D(L3,kernel_size=(3,3),strides=(2,2),activation='relu',padding='same',name='E3')(h)
h  = BatchNormalization()(h)
e  = Conv2D(L4,kernel_size=(2,2),strides=(1,1),activation='relu',padding='same',name='E4')(h)

# Decoding
h  = Conv2D(L4,kernel_size=(2,2),activation='relu',padding='same',name='D1')(e)
h  = UpSampling2D((2,2))(h)
h  = Conv2D(L3,kernel_size=(3,3),activation='relu',padding='same',name='D2')(h)
h  = UpSampling2D((2,2))(h)
h  = Conv2D(L2,kernel_size=(3,3),activation='relu',padding='same',name='D3')(h)
h  = UpSampling2D((2,2))(h)
h  = Conv2D(1,kernel_size=(5,5),activation='relu',padding='same',name='D4')(h)
y  = Lambda(lambda xx: K.squeeze(xx,3),name='Recon')(h)

# Laplacian
l = Lambda(laplacian,name='Laplacian')(x)
z = dot([y,l],axes=[1,2],name='Mre')
# z = dot([y,l],axes=-1,name='Mre')

# Build Model
model = Model(inputs=x,outputs=y)
model.summary()

# Build Aux Model
aux   = Model(inputs=x,outputs=[y,z])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 64, 64, 3)         0
# _________________________________________________________________
# E1 (Conv2D)                  (None, 32, 32, 64)        4864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# E2 (Conv2D)                  (None, 16, 16, 50)        28850
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 50)        200
# _________________________________________________________________
# E3 (Conv2D)                  (None, 8, 8, 32)          14432
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# E4 (Conv2D)                  (None, 8, 8, 32)          4128
# _________________________________________________________________
# D1 (Conv2D)                  (None, 8, 8, 32)          4128
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# D2 (Conv2D)                  (None, 16, 16, 32)        9248
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# D3 (Conv2D)                  (None, 32, 32, 50)        14450
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 50)        0
# _________________________________________________________________
# D4 (Conv2D)                  (None, 64, 64, 1)         1251
# _________________________________________________________________
# Recon (Lambda)               (None, 64, 64)            0
# =================================================================
# Total params: 81,935
# Trainable params: 81,643
# Non-trainable params: 292
# _________________________________________________________________

# %%
# Compiling Model
model.compile(loss='mse',optimizer='adam')
aux.compile(loss='mse',loss_weights=[1.0,3.0],optimizer='adam')

# %%
x_aux = np.linalg.norm(x_train,axis=-1)

# %%
# Train Model
log = aux.fit(x_train,[y_train,x_aux],
             epochs=nepoch,
             batch_size=nbatch)

# log = model.fit(x_train,y_train,
#           epochs=nepoch,
#           batch_size=nbatch,
#           validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0505 - Recon_loss: 0.0387 - Mre_loss: 0.0039
# Epoch 2/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0443 - Recon_loss: 0.0316 - Mre_loss: 0.0043
# Epoch 3/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0430 - Recon_loss: 0.0301 - Mre_loss: 0.0043
# Epoch 4/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0413 - Recon_loss: 0.0278 - Mre_loss: 0.0045
# Epoch 5/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0411 - Recon_loss: 0.0284 - Mre_loss: 0.0042
# Epoch 6/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0411 - Recon_loss: 0.0286 - Mre_loss: 0.0042
# Epoch 7/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0392 - Recon_loss: 0.0253 - Mre_loss: 0.0046
# Epoch 8/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0403 - Recon_loss: 0.0282 - Mre_loss: 0.0040
# Epoch 9/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0396 - Recon_loss: 0.0258 - Mre_loss: 0.0046
# Epoch 10/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0382 - Recon_loss: 0.0244 - Mre_loss: 0.0046
# Epoch 11/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0370 - Recon_loss: 0.0240 - Mre_loss: 0.0043
# Epoch 12/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0357 - Recon_loss: 0.0227 - Mre_loss: 0.0043
# Epoch 13/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0362 - Recon_loss: 0.0229 - Mre_loss: 0.0044
# Epoch 14/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0349 - Recon_loss: 0.0217 - Mre_loss: 0.0044
# Epoch 15/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0341 - Recon_loss: 0.0211 - Mre_loss: 0.0043
# Epoch 16/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0337 - Recon_loss: 0.0209 - Mre_loss: 0.0043
# Epoch 17/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0332 - Recon_loss: 0.0205 - Mre_loss: 0.0042
# Epoch 18/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0330 - Recon_loss: 0.0204 - Mre_loss: 0.0042
# Epoch 19/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0326 - Recon_loss: 0.0199 - Mre_loss: 0.0042
# Epoch 20/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0328 - Recon_loss: 0.0205 - Mre_loss: 0.0041
# Epoch 21/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0320 - Recon_loss: 0.0194 - Mre_loss: 0.0042
# Epoch 22/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0315 - Recon_loss: 0.0188 - Mre_loss: 0.0042
# Epoch 23/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0310 - Recon_loss: 0.0189 - Mre_loss: 0.0041
# Epoch 24/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0313 - Recon_loss: 0.0192 - Mre_loss: 0.0040
# Epoch 25/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0304 - Recon_loss: 0.0185 - Mre_loss: 0.0040
# Epoch 26/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0300 - Recon_loss: 0.0179 - Mre_loss: 0.0040
# Epoch 27/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0298 - Recon_loss: 0.0177 - Mre_loss: 0.0040
# Epoch 28/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0295 - Recon_loss: 0.0178 - Mre_loss: 0.0039
# Epoch 29/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0291 - Recon_loss: 0.0174 - Mre_loss: 0.0039
# Epoch 30/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0288 - Recon_loss: 0.0173 - Mre_loss: 0.0039
# Epoch 31/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0285 - Recon_loss: 0.0168 - Mre_loss: 0.0039
# Epoch 32/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0286 - Recon_loss: 0.0171 - Mre_loss: 0.0038
# Epoch 33/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0283 - Recon_loss: 0.0168 - Mre_loss: 0.0038
# Epoch 34/100
# 299/299 [==============================] - 9s 29ms/step - loss: 0.0280 - Recon_loss: 0.0166 - Mre_loss: 0.0038
# Epoch 35/100
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0278 - Recon_loss: 0.0164 - Mre_loss: 0.0038
# Epoch 36/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0281 - Recon_loss: 0.0168 - Mre_loss: 0.0038
# Epoch 37/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0285 - Recon_loss: 0.0173 - Mre_loss: 0.0037
# Epoch 38/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0288 - Recon_loss: 0.0171 - Mre_loss: 0.0039
# Epoch 39/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0279 - Recon_loss: 0.0166 - Mre_loss: 0.0038
# Epoch 40/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0275 - Recon_loss: 0.0161 - Mre_loss: 0.0038
# Epoch 41/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0277 - Recon_loss: 0.0166 - Mre_loss: 0.0037
# Epoch 42/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0276 - Recon_loss: 0.0162 - Mre_loss: 0.0038
# Epoch 43/100
# 299/299 [==============================] - 10s 35ms/step - loss: 0.0276 - Recon_loss: 0.0165 - Mre_loss: 0.0037
# Epoch 44/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0275 - Recon_loss: 0.0164 - Mre_loss: 0.0037
# Epoch 45/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0270 - Recon_loss: 0.0161 - Mre_loss: 0.0036
# Epoch 46/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0268 - Recon_loss: 0.0158 - Mre_loss: 0.0037
# Epoch 47/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0264 - Recon_loss: 0.0156 - Mre_loss: 0.0036
# Epoch 48/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0264 - Recon_loss: 0.0155 - Mre_loss: 0.0036
# Epoch 49/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0262 - Recon_loss: 0.0154 - Mre_loss: 0.0036
# Epoch 50/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0261 - Recon_loss: 0.0153 - Mre_loss: 0.0036
# Epoch 51/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0262 - Recon_loss: 0.0154 - Mre_loss: 0.0036
# Epoch 52/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0263 - Recon_loss: 0.0157 - Mre_loss: 0.0035
# Epoch 53/100
# 299/299 [==============================] - 9s 32ms/step - loss: 0.0260 - Recon_loss: 0.0153 - Mre_loss: 0.0036
# Epoch 54/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0258 - Recon_loss: 0.0151 - Mre_loss: 0.0036
# Epoch 55/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0259 - Recon_loss: 0.0152 - Mre_loss: 0.0035
# Epoch 56/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0258 - Recon_loss: 0.0149 - Mre_loss: 0.0036
# Epoch 57/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0264 - Recon_loss: 0.0156 - Mre_loss: 0.0036
# Epoch 58/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0262 - Recon_loss: 0.0154 - Mre_loss: 0.0036
# Epoch 59/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0261 - Recon_loss: 0.0153 - Mre_loss: 0.0036
# Epoch 60/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0257 - Recon_loss: 0.0151 - Mre_loss: 0.0035
# Epoch 61/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0254 - Recon_loss: 0.0148 - Mre_loss: 0.0035
# Epoch 62/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0253 - Recon_loss: 0.0149 - Mre_loss: 0.0035
# Epoch 63/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0253 - Recon_loss: 0.0147 - Mre_loss: 0.0035
# Epoch 64/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0255 - Recon_loss: 0.0149 - Mre_loss: 0.0035
# Epoch 65/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0251 - Recon_loss: 0.0146 - Mre_loss: 0.0035
# Epoch 66/100
# 299/299 [==============================] - 11s 38ms/step - loss: 0.0250 - Recon_loss: 0.0145 - Mre_loss: 0.0035
# Epoch 67/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0249 - Recon_loss: 0.0146 - Mre_loss: 0.0034
# Epoch 68/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0248 - Recon_loss: 0.0145 - Mre_loss: 0.0035
# Epoch 69/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0245 - Recon_loss: 0.0143 - Mre_loss: 0.0034
# Epoch 70/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0246 - Recon_loss: 0.0143 - Mre_loss: 0.0034
# Epoch 71/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0246 - Recon_loss: 0.0143 - Mre_loss: 0.0034
# Epoch 72/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0246 - Recon_loss: 0.0144 - Mre_loss: 0.0034
# Epoch 73/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0245 - Recon_loss: 0.0142 - Mre_loss: 0.0034
# Epoch 74/100
# 299/299 [==============================] - 10s 34ms/step - loss: 0.0244 - Recon_loss: 0.0143 - Mre_loss: 0.0034
# Epoch 75/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0242 - Recon_loss: 0.0140 - Mre_loss: 0.0034
# Epoch 76/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0244 - Recon_loss: 0.0141 - Mre_loss: 0.0034
# Epoch 77/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0243 - Recon_loss: 0.0141 - Mre_loss: 0.0034
# Epoch 78/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0243 - Recon_loss: 0.0142 - Mre_loss: 0.0034
# Epoch 79/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0242 - Recon_loss: 0.0140 - Mre_loss: 0.0034
# Epoch 80/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0242 - Recon_loss: 0.0140 - Mre_loss: 0.0034
# Epoch 81/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0241 - Recon_loss: 0.0140 - Mre_loss: 0.0034
# Epoch 82/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0242 - Recon_loss: 0.0141 - Mre_loss: 0.0034
# Epoch 83/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0244 - Recon_loss: 0.0142 - Mre_loss: 0.0034
# Epoch 84/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0241 - Recon_loss: 0.0139 - Mre_loss: 0.0034
# Epoch 85/100
# 299/299 [==============================] - 9s 30ms/step - loss: 0.0242 - Recon_loss: 0.0139 - Mre_loss: 0.0034
# Epoch 86/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0243 - Recon_loss: 0.0142 - Mre_loss: 0.0034
# Epoch 87/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0245 - Recon_loss: 0.0142 - Mre_loss: 0.0034
# Epoch 88/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0243 - Recon_loss: 0.0139 - Mre_loss: 0.0034
# Epoch 89/100
# 299/299 [==============================] - 9s 32ms/step - loss: 0.0241 - Recon_loss: 0.0139 - Mre_loss: 0.0034
# Epoch 90/100
# 299/299 [==============================] - 10s 33ms/step - loss: 0.0239 - Recon_loss: 0.0138 - Mre_loss: 0.0034
# Epoch 91/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0239 - Recon_loss: 0.0138 - Mre_loss: 0.0034
# Epoch 92/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0238 - Recon_loss: 0.0137 - Mre_loss: 0.0034
# Epoch 93/100
# 299/299 [==============================] - 11s 36ms/step - loss: 0.0236 - Recon_loss: 0.0137 - Mre_loss: 0.0033
# Epoch 94/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0235 - Recon_loss: 0.0136 - Mre_loss: 0.0033
# Epoch 95/100
# 299/299 [==============================] - 11s 37ms/step - loss: 0.0238 - Recon_loss: 0.0137 - Mre_loss: 0.0034
# Epoch 96/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0240 - Recon_loss: 0.0137 - Mre_loss: 0.0034
# Epoch 97/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0240 - Recon_loss: 0.0138 - Mre_loss: 0.0034
# Epoch 98/100
# 299/299 [==============================] - 10s 32ms/step - loss: 0.0238 - Recon_loss: 0.0139 - Mre_loss: 0.0033
# Epoch 99/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0240 - Recon_loss: 0.0138 - Mre_loss: 0.0034
# Epoch 100/100
# 299/299 [==============================] - 9s 31ms/step - loss: 0.0237 - Recon_loss: 0.0138 - Mre_loss: 0.0033

# %%
# Plot Loss Curves
mloss = log.history['Mre_loss']
rloss = log.history['Recon_loss']
nepch = log.epoch

plt.figure(figsize=(8,3))
plt.subplot(121), plt.plot(nepch,rloss),plt.title('Recon Loss')
plt.subplot(122), plt.plot(nepch,mloss,'g'),plt.title('Mre Loss')
plt.tight_layout()

# %% [markdown]
# ## Model Evaluation

# %%
# Generate Predictions
y_pred = model.predict(x_test)

# %%
# Visualize Examples
N   = 5
row = 2
col = N

sidx = random.sample(range(len(y_pred)),N)

fig,axs = plt.subplots(row,col,sharex='col',sharey='row',figsize=(14,6))
for i,n in enumerate(sidx):
    axs[0,i%col].imshow(y_test[n])
    axs[1,i%col].imshow(y_pred[n])
    
    mse = mean_squared_error(y_pred[n],y_test[n])
    header = '{0}, mse={1:.04f}'.format(n,mse)
    axs[0,i%col].set_title(header)
